# %%
import json
import pandas as pd
from dataReader import *

# %%
acl = DataReader(json_name="./acl-arc/test.jsonl")
acl.get_stats()
# Out:
#                                                 text citing_paper_id  \
# 0  Resnik ( 1995 ) reported a correlation of r = ...        W06-1104
# 1  Similar observation for surface word frequency...        P13-3018
# 2  But their importance has grown far beyond mach...        J10-3007
# 3  Previous sentiment-analysis work in different ...        W06-1639
# 4  However , the method we are currently using in...        J92-1004
#
#    cited_paper_id  citing_paper_year  cited_paper_year  \
# 0   External_3502               2006              1995
# 1  External_90447               2013              1980
# 2        N01-1026               2010              2001
# 3        W06-3808               2006              2006
# 4        H91-1014               1992              1991
#
#                                   citing_paper_title  \
# 0  a holistic lexiconbased approach to opinion mi...
# 1  a holistic lexiconbased approach to opinion mi...
# ...

# %%
acl.df['text'][0]
# Out:
# 'Resnik ( 1995 ) reported a correlation of r = .9026.10 The results are not directly comparable , because he only used noun-noun pairs , words instead of concepts , a much smaller dataset , and measured semantic similarity instead of semantic relatedness .'
